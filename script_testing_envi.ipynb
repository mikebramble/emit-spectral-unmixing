# %%
# Code written by: Michael Bramble | michael.s.bramble@jpl.nasa.gov
# testing the process for loading EMIT minearl product 5x5 deg mosaics
# 20240321 - initial version

# import spectral
from spectral.io import envi
# import spectral.io.envi as envi
# from spectral import *

# import earthaccess
import os
import numpy as np
import math
import xarray as xr
import holoviews as hv
import hvplot.xarray # noqa
# import netCDF4 as nc
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap, BoundaryNorm
# import earthpy.plot as ep
import sys
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
## LOAD EMIT MOSAIC

image_dir = '/Users/bramble/Documents/emit_min_mosaics/glts_5_cloudy_20240120_global/l2b/min_-110_-105_30_35.hdr'
mosaic_image = envi.open(image_dir)#.load()
# mosaic_image = open_image(image_dir)
# mosaic_image

band_group_1_min = mosaic_image.read_band(1)
band_group_2_min = mosaic_image.read_band(3)

mosaic_image.metadata
# mosaic_image.metadata['band names']
# mosaic_image.metadata['map info']
# mosaic_image.metadata['data ignore value']
# lines = int(mosaic_image.metadata['lines'])
# mosaic_image.metadata['coordinate system string']
# Out:
# {'description': 'glts_5_cloudy_20240120_global/l2b/min_-110_-105_30_35',
#  'samples': '9091',
#  'lines': '9093',
#  'bands': '4',
#  'header offset': '0',
#  'file type': 'ENVI Standard',
#  'data type': '4',
#  'interleave': 'bil',
#  'byte order': '0',
#  'map info': ['Geographic Lat/Lon',
#   '1',
#   '1',
#   '-110',
#   '35.00035',
#   '0.00055',
#   '0.00055',
#   'WGS-84'],
#  'coordinate system string': ['GEOGCS["GCS_WGS_1984"',
#   'DATUM["D_WGS_1984"',
#   'SPHEROID["WGS_1984"',
#   '6378137.0',
#   '298.257223563]]',
#   'PRIMEM["Greenwich"',
#   '0.0]',
#   'UNIT["Degree"',
#   '0.0174532925199433]]'],
#  'band names': ['Group 1 Band Depth',
#   'Group 1 Index',
#   'Group 2 Band Depth',
#   'Group 2 Index'],
#  'data ignore value': '-9999'}

# %%
## VISUALIZE DATA

# view = imshow(band_group_1_min)
# band_group_1_min.hvplot

band_group_1_min[band_group_1_min == int(mosaic_image.metadata['data ignore value'])] = np.nan

plt.imshow(band_group_1_min,cmap='viridis')
plt.colorbar()

# %%
# band_group_1_min.hvplot
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # band_group_1_min.hvplot
# ----> 2 mosaic_image.metadata.map_info['upper left corner map coordinates']
#
# NameError: name 'mosaic_image' is not defined
